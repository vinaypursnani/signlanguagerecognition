# BEAUTIFUL (4).jpg
# ...

# %%
# Get Tuple for splitting file extension
for f in os.listdir():
    print(os.path.splitext(f))
# Out:
# ('A LOT (1)', '.jpg')
# ('A LOT (2)', '.jpg')
# ('A LOT (3)', '.jpg')
# ('A LOT (4)', '.jpg')
# ('ABUSE (1)', '.jpg')
# ('ABUSE (2)', '.jpg')
# ('ABUSE (3)', '.jpg')
# ('ABUSE (4)', '.jpg')
# ('ABUSE (5)', '.jpg')
# ('AFRAID (1)', '.jpg')
# ('AFRAID (2)', '.jpg')
# ('AFRAID (3)', '.jpg')
# ('AFRAID (4)', '.jpg')
# ('AFRAID (5)', '.jpg')
# ('AFRAID (6)', '.jpg')
# ('AGE (1)', '.jpg')
# ('AGE (2)', '.jpg')
# ('AGE (3)', '.jpg')
# ('AGE (4)', '.jpg')
# ('AGE (5)', '.jpg')
# ('AGE', '.jpg')
# ('AGREE (1)', '.jpg')
# ('AGREE (2)', '.jpg')
# ('AGREE (3)', '.jpg')
# ('AGREE (4)', '.jpg')
# ('AGREE (5)', '.jpg')
# ('AGREE (6)', '.jpg')
# ('AGREE (7)', '.jpg')
# ('ALL (1)', '.jpg')
# ('ALL (2)', '.jpg')
# ('ALL (3)', '.jpg')
# ('ALL (4)', '.jpg')
# ('ANGRY (1)', '.jpg')
# ('ANGRY (10)', '.jpg')
# ('ANGRY (2)', '.jpg')
# ('ANGRY (3)', '.jpg')
# ('ANGRY (4)', '.jpg')
# ('ANGRY (5)', '.jpg')
# ('ANGRY (6)', '.jpg')
# ('ANGRY (7)', '.jpg')
# ('ANGRY (8)', '.jpg')
# ('ANGRY (9)', '.jpg')
# ...

# %%
for f in os.listdir():
    file_name, file_ext = os.path.splitext(f)
    # print(file_name, file_ext)
   # new_name = '{}.{}{}'.format(file_name.replace(' ','')[:-3],str(uuid.uuid1()),file_ext)
    # print(imagename)
    #os.rename(f, new_name)
    file_name = file_name.replace(' ','')
    file_name = file_name.replace('(','')
    file_name = file_name.replace(')','')
    file_name = file_name.replace('-','')
    file_name = file_name.upper()
    file_name = ''.join([i for i in file_name if not i.isdigit()])
    new_name = '{}.{}{}'.format(file_name,str(uuid.uuid1()),file_ext)
    #print(new_name)
    os.rename(f, new_name)

# %%
# Out:
# combyourhair.b9978ba1-d074-11eb-88fb-5405db33d107.jpg
# combyourhair.b9978ba2-d074-11eb-89aa-5405db33d107.jpg
# combyourhair.b997b9df-d074-11eb-a838-5405db33d107.jpg
# combyourhair.b997b9e0-d074-11eb-8bb9-5405db33d107.jpg
# combyourhair.b997d9c0-d074-11eb-9075-5405db33d107.jpg
# combyourhair.b997d9c1-d074-11eb-9634-5405db33d107.jpg
# combyourhair.b997d9c2-d074-11eb-aa6d-5405db33d107.jpg
# combyourhair.b99800c7-d074-11eb-a830-5405db33d107.jpg
# combyourhair.b99800c8-d074-11eb-84fc-5405db33d107.jpg
# combyourhair.b99800c9-d074-11eb-af93-5405db33d107.jpg
# combyourhair.b9982897-d074-11eb-9643-5405db33d107.jpg
# combyourhair.b9982898-d074-11eb-9600-5405db33d107.jpg
# combyourhair.b9982899-d074-11eb-a97a-5405db33d107.jpg
# combyourhair.b9984ee1-d074-11eb-8699-5405db33d107.jpg
# combyourhair.b9984ee2-d074-11eb-8367-5405db33d107.jpg
# combyourhair.b9984ee3-d074-11eb-b101-5405db33d107.jpg
# combyourhair.b99875fd-d074-11eb-adfa-5405db33d107.jpg
# ...
